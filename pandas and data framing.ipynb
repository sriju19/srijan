# %%
import numpy as np
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\Srijan\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
dict1={
    "name":["srijan","swetha","chandu"],
    "marks":[23,33,32],
    "city":["Telangana","chennai","andra pradesh"]
}

# %%
df=pd.DataFrame(dict1)#used to create a dict into excel

# %%
df
# Out:
#      name  marks           city
# 0  srijan     23      Telangana
# 1  swetha     33        chennai
# 2  chandu     32  andra pradesh

# %%
df["name"]#accessing separate columns
# Out:
# 0    srijan
# 1    swetha
# 2    chandu
# Name: name, dtype: object

# %%
#to remove the index
df.to_csv('friend.csv', index=False)#reading the csv file

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   29.333333
# std     5.507571
# min    23.000000
# 25%    27.500000
# 50%    32.000000
# 75%    32.500000
# max    33.000000

# %%
df.head(2)
# Out:
#      name  marks       city
# 0  srijan     23  Telangana
# 1  swetha     33    chennai

# %%
df.tail(2)
# Out:
#      name  marks           city
# 1  swetha     33        chennai
# 2  chandu     32  andra pradesh

# %%
srij=pd.read_csv("C:\\Users\\Srijan\\OneDrive\\Desktop\\New folder (2)\\android-games.csv", index_col=False)#reading csv file
srij
# Out:
#       rank                                         title  total ratings  \
# 0        1                Garena Free Fire- World Series       86273129
# 1        2                        PUBG MOBILE - Traverse       37276732
# 2        3                     Mobile Legends: Bang Bang       26663595
# 3        4                                   Brawl Stars       17971552
# 4        5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...    ...                                           ...            ...
# 1725    96                 زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726    97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727    98                  Scrabble® GO - New Word Game         110723
# 1728    99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729   100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
srij.describe()
# Out:
#               rank  total ratings  average rating  growth (30 days)  \
# count  1730.000000   1.730000e+03     1730.000000       1730.000000
# mean     50.386705   1.064332e+06        3.908092        321.735896
# std      28.936742   3.429250e+06        0.290973       6018.914507
# min       1.000000   3.299300e+04        2.000000          0.000000
# 25%      25.000000   1.759992e+05        4.000000          0.100000
# 50%      50.000000   4.286065e+05        4.000000          0.500000
# 75%      75.000000   8.837970e+05        4.000000          1.700000
# max     100.000000   8.627313e+07        4.000000     227105.700000
#
#        growth (60 days)        price  5 star ratings  4 star ratings  \
# count       1730.000000  1730.000000    1.730000e+03    1.730000e+03
# mean         122.554971     0.010942    7.622315e+05    1.164366e+05
# std         2253.891703     0.214987    2.538658e+06    3.021631e+05
# min            0.000000     0.000000    1.397500e+04    2.451000e+03
# ...

# %%
srij.
# Out:
#   Input In [31]
#     srij.
#          ^
# SyntaxError: invalid syntax

# %%
srij.sort_index(axis=0, ascending=False)#reverses the order of the dataframe which id row if axis 1 then columns reverses
# Out:
#       rank                                         title  total ratings  \
# 1729   100                                  Pinturillo 2         108917
# 1728    99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1727    98                  Scrabble® GO - New Word Game         110723
# 1726    97     Bible Word Puzzle - Free Bible Word Games         111595
# 1725    96                 زوايا - لعبة ستحرك زوايا عقلك         112408
# ...    ...                                           ...            ...
# 4        5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# 3        4                                   Brawl Stars       17971552
# 2        3                     Mobile Legends: Bang Bang       26663595
# 1        2                        PUBG MOBILE - Traverse       37276732
# 0        1                Garena Free Fire- World Series       86273129
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
srij['rank'][0]="harry"#replacing the elemnt with name1
# Out:
# C:\Users\Srijan\AppData\Local\Temp\ipykernel_69528\274800774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   srij['rank'][0]="harry"#replacing the elemnt with name1

# %%
srij
# Out:
#        rank                                         title  total ratings  \
# 0     harry                Garena Free Fire- World Series       86273129
# 1         2                        PUBG MOBILE - Traverse       37276732
# 2         3                     Mobile Legends: Bang Bang       26663595
# 3         4                                   Brawl Stars       17971552
# 4         5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...     ...                                           ...            ...
# 1725     96                 زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726     97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727     98                  Scrabble® GO - New Word Game         110723
# 1728     99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729    100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
srij.loc[0,'rank']=655 #replacing the elemnt in a index

# %%
srij
# Out:
#      rank                                         title  total ratings  \
# 0     655                Garena Free Fire- World Series       86273129
# 1       2                        PUBG MOBILE - Traverse       37276732
# 2       3                     Mobile Legends: Bang Bang       26663595
# 3       4                                   Brawl Stars       17971552
# 4       5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...   ...                                           ...            ...
# 1725   96                 زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726   97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727   98                  Scrabble® GO - New Word Game         110723
# 1728   99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729  100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
srij.drop(0)#removing a row
# Out:
#      rank                                              title  total ratings  \
# 1       2                             PUBG MOBILE - Traverse       37276732
# 2       3                          Mobile Legends: Bang Bang       26663595
# 3       4                                        Brawl Stars       17971552
# 4       5       Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# 5       6  Call of Duty®: Mobile - Season 4: Spurned & Bu...       13572148
# ...   ...                                                ...            ...
# 1725   96                      زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726   97          Bible Word Puzzle - Free Bible Word Games         111595
# 1727   98                       Scrabble® GO - New Word Game         110723
# 1728   99           Word Nut: Word Puzzle Games & Crosswords         109530
# 1729  100                                       Pinturillo 2         108917
#
# ...

# %%
srij.drop("paid", axis=1)#removes the columns
# Out:
#      rank                                         title  total ratings  \
# 0     655                Garena Free Fire- World Series       86273129
# 1       2                        PUBG MOBILE - Traverse       37276732
# 2       3                     Mobile Legends: Bang Bang       26663595
# 3       4                                   Brawl Stars       17971552
# 4       5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...   ...                                           ...            ...
# 1725   96                 زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726   97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727   98                  Scrabble® GO - New Word Game         110723
# 1728   99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729  100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
srij.loc[[1,2], :]
# Out:
#   rank                      title  total ratings installs  average rating  \
# 1    2     PUBG MOBILE - Traverse       37276732  500.0 M               4
# 2    3  Mobile Legends: Bang Bang       26663595  100.0 M               4
#
#    growth (30 days)  growth (60 days)  price     category  5 star ratings  \
# 1               1.8               3.6    0.0  GAME ACTION        28339753
# 2               1.5               3.2    0.0  GAME ACTION        18777988
#
#    4 star ratings  3 star ratings  2 star ratings  1 star ratings   paid
# 1         2164478         1253185          809821         4709492  False
# 2         1812094         1050600          713912         4308998  False

# %%
srij.loc[(srij["average rating"]>1)]#data greater than parameter
# Out:
#      rank                                         title  total ratings  \
# 0     655                Garena Free Fire- World Series       86273129
# 1       2                        PUBG MOBILE - Traverse       37276732
# 2       3                     Mobile Legends: Bang Bang       26663595
# 3       4                                   Brawl Stars       17971552
# 4       5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...   ...                                           ...            ...
# 1725   96                 زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726   97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727   98                  Scrabble® GO - New Word Game         110723
# 1728   99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729  100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
srij.loc[2, "rank"]
# Out:
# 3

# %%
srij.drop([0])#to drop rows defualt if colums take another arguements as axis=1
# Out:
#      rank                                              title  total ratings  \
# 1       2                             PUBG MOBILE - Traverse       37276732
# 2       3                          Mobile Legends: Bang Bang       26663595
# 3       4                                        Brawl Stars       17971552
# 4       5       Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# 5       6  Call of Duty®: Mobile - Season 4: Spurned & Bu...       13572148
# ...   ...                                                ...            ...
# 1725   96                      زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726   97          Bible Word Puzzle - Free Bible Word Games         111595
# 1727   98                       Scrabble® GO - New Word Game         110723
# 1728   99           Word Nut: Word Puzzle Games & Crosswords         109530
# 1729  100                                       Pinturillo 2         108917
#
# ...

# %%
srij.drop([1725], inplace=True)#drops orginally

# %%
srij
# Out:
#      rank                                         title  total ratings  \
# 0     655                Garena Free Fire- World Series       86273129
# 1       2                        PUBG MOBILE - Traverse       37276732
# 2       3                     Mobile Legends: Bang Bang       26663595
# 3       4                                   Brawl Stars       17971552
# 4       5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...   ...                                           ...            ...
# 1724   95                             4 Fotos 1 Palavra         115437
# 1726   97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727   98                  Scrabble® GO - New Word Game         110723
# 1728   99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729  100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
srij.dropna(how="all", axis=1)#drops nulls from columns
# Out:
#      rank                                         title  total ratings  \
# 0     655                Garena Free Fire- World Series       86273129
# 1       2                        PUBG MOBILE - Traverse       37276732
# 2       3                     Mobile Legends: Bang Bang       26663595
# 3       4                                   Brawl Stars       17971552
# 4       5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...   ...                                           ...            ...
# 1724   95                             4 Fotos 1 Palavra         115437
# 1726   97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727   98                  Scrabble® GO - New Word Game         110723
# 1728   99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729  100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
srij.drop_duplicates(subset=['price'], keep=False)#removes duplicates from price
# Out:
#      rank      title  total ratings installs  average rating  \
# 209    10  Minecraft        4100452   10.0 M               4
# 477    60     Reigns         146718  500.0 k               4
# 923    98  Muse Dash          34140  100.0 k               4
# 1217   92   Evertale         311126    1.0 M               4
#
#       growth (30 days)  growth (60 days)  price           category  \
# 209              234.3               2.4   7.49        GAME ARCADE
# 477                0.1               0.1   2.99          GAME CARD
# 923              768.5               6.7   1.49         GAME MUSIC
# 1217             725.3               5.1   0.99  GAME ROLE PLAYING
#
#       5 star ratings  4 star ratings  3 star ratings  2 star ratings  \
# 209          3324435          317144          135048           65677
# 477           108356           25417            5887            2868
# 923            29210            2774             718             429
# ...

# %%
srij.info()#checks then nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1729 entries, 0 to 1729
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              1729 non-null   object
#  1   title             1729 non-null   object
#  2   total ratings     1729 non-null   int64
#  3   installs          1729 non-null   object
#  4   average rating    1729 non-null   int64
#  5   growth (30 days)  1729 non-null   float64
#  6   growth (60 days)  1729 non-null   float64
#  7   price             1729 non-null   float64
#  8   category          1729 non-null   object
#  9   5 star ratings    1729 non-null   int64
#  10  4 star ratings    1729 non-null   int64
#  11  3 star ratings    1729 non-null   int64
#  12  2 star ratings    1729 non-null   int64
#  13  1 star ratings    1729 non-null   int64
#  14  paid              1729 non-null   bool
# dtypes: bool(1), float64(3), int64(7), object(4)
# memory usage: 204.3+ KB

# %%
srij.isnull()
# Out:
#        rank  title  total ratings  installs  average rating  growth (30 days)  \
# 0     False  False          False     False           False             False
# 1     False  False          False     False           False             False
# 2     False  False          False     False           False             False
# 3     False  False          False     False           False             False
# 4     False  False          False     False           False             False
# ...     ...    ...            ...       ...             ...               ...
# 1724  False  False          False     False           False             False
# 1726  False  False          False     False           False             False
# 1727  False  False          False     False           False             False
# 1728  False  False          False     False           False             False
# 1729  False  False          False     False           False             False
#
# ...

# %%
srij.notnull()
# Out:
#       rank  title  total ratings  installs  average rating  growth (30 days)  \
# 0     True   True           True      True            True              True
# 1     True   True           True      True            True              True
# 2     True   True           True      True            True              True
# 3     True   True           True      True            True              True
# 4     True   True           True      True            True              True
# ...    ...    ...            ...       ...             ...               ...
# 1724  True   True           True      True            True              True
# 1726  True   True           True      True            True              True
# 1727  True   True           True      True            True              True
# 1728  True   True           True      True            True              True
# 1729  True   True           True      True            True              True
#
# ...

# %%
total=srij.price.sum()
print(total)
# Out:
# 18.93

# %%
f=srij.growth(60days).sum()
# Out:
#   Input In [51]
#     f=srij.growth(60days).sum()
#                     ^
# SyntaxError: invalid syntax

# %%
srij.rename(columns={'total ratings':'total'}, inplace=True)

# %%
srij
# Out:
#      rank                                         title     total installs  \
# 0     655                Garena Free Fire- World Series  86273129  500.0 M
# 1       2                        PUBG MOBILE - Traverse  37276732  500.0 M
# 2       3                     Mobile Legends: Bang Bang  26663595  100.0 M
# 3       4                                   Brawl Stars  17971552  100.0 M
# 4       5  Sniper 3D: Fun Free Online FPS Shooting Game  14464235  500.0 M
# ...   ...                                           ...       ...      ...
# 1724   95                             4 Fotos 1 Palavra    115437    5.0 M
# 1726   97     Bible Word Puzzle - Free Bible Word Games    111595    1.0 M
# 1727   98                  Scrabble® GO - New Word Game    110723   10.0 M
# 1728   99      Word Nut: Word Puzzle Games & Crosswords    109530    5.0 M
# 1729  100                                  Pinturillo 2    108917   10.0 M
#
# ...

# %%
srij.total.sum()
# Out:
# 1841181813

# %%
srij.rename(columns={'average rating':'average_ratings'}, inplace=True)

# %%
srij
# Out:
#      rank                                         title     total installs  \
# 0     655                Garena Free Fire- World Series  86273129  500.0 M
# 1       2                        PUBG MOBILE - Traverse  37276732  500.0 M
# 2       3                     Mobile Legends: Bang Bang  26663595  100.0 M
# 3       4                                   Brawl Stars  17971552  100.0 M
# 4       5  Sniper 3D: Fun Free Online FPS Shooting Game  14464235  500.0 M
# ...   ...                                           ...       ...      ...
# 1724   95                             4 Fotos 1 Palavra    115437    5.0 M
# 1726   97     Bible Word Puzzle - Free Bible Word Games    111595    1.0 M
# 1727   98                  Scrabble® GO - New Word Game    110723   10.0 M
# 1728   99      Word Nut: Word Puzzle Games & Crosswords    109530    5.0 M
# 1729  100                                  Pinturillo 2    108917   10.0 M
#
# ...

# %%
srij.average_ratings.sum()#this helps in adding up the values of the columns and if any space found in renaming the srij.average rating use the above function
# Out:
# 6757

# %%
# !pip install pandas-profiling
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\Srijan\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
from pandas_profiling import ProfileReport

# %%
srij

# %%
srij

# %%
profile=ProfileReport(srij#report generation

# %%
profile.to_file(output_file="srij.html")#to generate a report and creates a html file in new folder.when output file is in html.

# %%
srij
# Out:
#      rank                                         title     total installs  \
# 0     655                Garena Free Fire- World Series  86273129  500.0 M
# 1       2                        PUBG MOBILE - Traverse  37276732  500.0 M
# 2       3                     Mobile Legends: Bang Bang  26663595  100.0 M
# 3       4                                   Brawl Stars  17971552  100.0 M
# 4       5  Sniper 3D: Fun Free Online FPS Shooting Game  14464235  500.0 M
# ...   ...                                           ...       ...      ...
# 1724   95                             4 Fotos 1 Palavra    115437    5.0 M
# 1726   97     Bible Word Puzzle - Free Bible Word Games    111595    1.0 M
# 1727   98                  Scrabble® GO - New Word Game    110723   10.0 M
# 1728   99      Word Nut: Word Puzzle Games & Crosswords    109530    5.0 M
# 1729  100                                  Pinturillo 2    108917   10.0 M
#
# ...
